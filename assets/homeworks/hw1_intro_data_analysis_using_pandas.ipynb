# %% [markdown]
# # Introduction to Data Analysis Using Pandas
#
# Practice applying Pandas for data loading, preprocessing, and exploratory analysis using a real-world country-level dataset from the FAO (Food and Agriculture Organization).
#
# ***Summary***
# 1. [Reading Data](#part-1)
# 2. [Data Preprocessing](#part-2)
# 3. [Exploratory Data Analysis - Visualization](#part-3)
# 4. [Exploratory Data Analysis - Statistical Analysis](#part-4)
# 5. [Generalization](#part-5)

# %% [markdown]
# ***
# <a id='part-1'></a>
# ## 1. Reading Data
#
# Load the FAO water data and practice fundamental Pandas I/O and inspection methods.

# %%
# Load required modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Data description
# >Data source: http://www.fao.org/nr/water/aquastat/data/query/index.html<br>
# >Data, units:<br>
# >* GDP, current USD (CPI adjusted)<br>
# >* NRI, mm/yr<br>
# >* Population density, inhab/km^2<br>
# >* Total area of the country, 1000 ha = 10km^2<br>
# >* Total Population, unit 1000 inhabitants<br>
#
# ___

# %% [markdown]
# **Q1 a) Read the CSV file `assets/data/data3.csv` into a DataFrame. Store it in a variable named `df`.**
#
# *Hint:* Use [`pd.read_csv()`](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)

# %%
### YOUR CODE HERE ###
df = ...

# %% [markdown]
# **Q1 b) Display the first 10 rows of `df`.**
#
# *Hint:* Use [`.head()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html)

# %%
### YOUR CODE HERE ###
...

# %% [markdown]
# **Q1 c) Display the column names of `df`.**
#
# *Hint:* Use [`.columns`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.columns.html)

# %%
### YOUR CODE HERE ###
...

# %% [markdown]
# **Q1 d) Use `.iloc` to display the first 3 rows and first 4 columns.**
#
# *Hint:* Use [`.iloc`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html)

# %%
### YOUR CODE HERE ###
...

# %% [markdown]
# ***
# <a id='part-2'></a>
# ## 2. Data Preprocessing
#
# Clean and reshape the raw data before analysis - handling missing values, duplicates, and type conversions.

# %% [markdown]
# **Q2 a) Find all rows where the `'Symbol'` column is `NaN`. Display the first 5.**
#
# *Hint:* Use [`pd.isna()`](https://pandas.pydata.org/docs/reference/api/pandas.isna.html) as a mask

# %%
### YOUR CODE HERE ###
...

# %% [markdown]
# **Q2 b) Remove missing-value rows and columns. Drop the column `'Other'` (all NaN), then drop all remaining rows containing any NaN. Store the result in place.**
#
# (1) Drop the `'Other'` column. (2) Drop rows with any NaN. (3) Use `inplace=True`. (4) Display the last 5 rows.
#
# *Hint:* Use [`.drop()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html) and [`.dropna()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html)

# %%
### YOUR CODE HERE ###
...

# %% [markdown]
# **Q2 c) Remove duplicate columns. Use [`.drop_duplicates()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html) and [`.duplicated()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.duplicated.html) to find and remove redundant columns. Store the result in `df`.**

# %%
### YOUR CODE HERE ###
...

# %% [markdown]
# **Q2 d) Remove duplicate rows. Apply the same approach to remove duplicate rows. Store the result in `df`.**

# %%
### YOUR CODE HERE ###
...

# %% [markdown]
# **Q2 e) Display all unique values in `df` for the columns `Area`, `Variable Name`, and `Year`.**
#
# *Hint:* Use [`.unique()`](https://pandas.pydata.org/docs/reference/api/pandas.Series.unique.html)

# %%
### YOUR CODE HERE ###
...

# %% [markdown]
# **Q2 f) Convert the `'Year'` column to pandas datetime objects where each year is the first day of that calendar year (e.g. `1962.0` becomes `1962-01-01`). Display the first 5 rows.**
#
# *Hint:* Use [`pd.to_datetime()`](https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html)

# %%
### YOUR CODE HERE ###
...

# %% [markdown]
# ***
# <a id='part-3'></a>
# ## 3. Exploratory Data Analysis - Visualization
#
# Visualize the distribution and trends in the data using Pandas built-in plotting and Matplotlib.

# %% [markdown]
# **Q3 a) Plot a bar chart showing the count for each unique value in the `'Area'` column. Give it a title.**
#
# *Hint:* Use [`.value_counts().plot.bar()`](https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html)

# %%
### YOUR CODE HERE ###
...

# %% [markdown]
# **Q3 b) Filter `df` to rows where `'Area'` is `'Iceland'`. Store the result in `df_iceland`. Then plot a line chart of the `'Value'` column over `'Year'` for Iceland. Add a title and axis labels.**
#
# *Hint:* Use [`.plot()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html) with `kind='line'`

# %%
### YOUR CODE HERE ###
df_iceland = ...

# plot line chart

# %% [markdown]
# **Q3 c) Create a scatter plot of `'Value'` vs `'Year'` for all rows in `df` where `'Variable Name'` is `'Total Population'`. Color the points by `'Area'`. Add a title.**
#
# *Hint:* Use [`plt.scatter()`](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html)

# %%
### YOUR CODE HERE ###
df_pop = ...

# scatter plot

# %% [markdown]
# ***
# <a id='part-4'></a>
# ## 4. Exploratory Data Analysis - Statistical Analysis
#
# Apply groupby, filtering, and aggregation to extract quantitative insights from the dataset.

# %% [markdown]
# **Q4 a) Create a DataFrame `df_usa` containing only rows where `'Area'` is `'United States of America'`. Set the `'Year'` column as the index using `.set_index()` with `inplace=True`. Display the head.**
#
# *Hint:* Use [`.set_index()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html)

# %%
### YOUR CODE HERE ###
df_usa = ...

#print(df_usa.head())

# %% [markdown]
# **Q4 b) Pivot `df_usa` so the unique values in `'Variable Name'` become columns and `'Value'` fills them. Use [`.unstack()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.unstack.html) after a groupby. Store the result back in `df_usa`. Display the head.**

# %%
### YOUR CODE HERE ###
...

# %% [markdown]
# **Q4 c) Rename the new columns to `['GDP', 'NRI', 'PD', 'Area', 'Population']`. Display the head.**
#
# *Hint:* Use [`.rename(columns=...)`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html)

# %%
### YOUR CODE HERE ###
...

# %% [markdown]
# **Q4 d) Replace all `NaN` values in `df_usa` with `0`. Display the head.**
#
# *Hint:* Use [`.fillna()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html)

# %%
### YOUR CODE HERE ###
...

# %% [markdown]
# **Q4 e) Multiply the `'Area'` column by `10` to convert from 1000 ha to 100 ha (= 1 km^2). Display the head.**

# %%
### YOUR CODE HERE ###
...

# %% [markdown]
# **Q4 f) Create a new column `'GDP/capita'` containing GDP per capita rounded to 2 decimal places.**
#
# $$GDP~per~capita = \\frac{GDP}{Population} \\times 1000$$
#
# where GDP is in current USD and Population is in thousands of inhabitants.
#
# *Hint:* Use [`.round()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.round.html)

# %%
### YOUR CODE HERE ###
...

# %% [markdown]
# **Q4 g) Find the maximum value of the `'NRI'` column in `df_usa`. What year does it occur? Display both values.**
#
# *Hint:* Use [`.idxmax()`](https://pandas.pydata.org/docs/reference/api/pandas.Series.idxmax.html)

# %%
### YOUR CODE HERE ###
nri_max = ...
nri_max_year = ...

#print(nri_max, nri_max_year)

# %% [markdown]
# ***
# <a id='part-5'></a>
# ## 5. Generalization
#
# Apply the same inspection and aggregation techniques to a new dataset - the classic Iris flower dataset. This confirms you can transfer the skill rather than adapt the code you wrote above.

# %%
from sklearn.datasets import load_iris

iris_bunch = load_iris(as_frame=True)
df_iris = iris_bunch.frame          # DataFrame with 4 feature columns + target
df_iris['species'] = df_iris['target'].map(dict(enumerate(iris_bunch.target_names)))
df_iris.head()

# %% [markdown]
# **Q5 a) Display `.info()` and `.describe()` for `df_iris`. What are the data types of each column?**

# %%
### YOUR CODE HERE ###
...

# %% [markdown]
# **Q5 b) Group `df_iris` by `'species'` and compute the mean of each numeric column. Store the result in `species_means` and display it.**
#
# *Hint:* Use [`.groupby().mean()`](https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.DataFrameGroupBy.mean.html)

# %%
### YOUR CODE HERE ###
species_means = ...

#display(species_means)

# %% [markdown]
# **Q5 c) Filter `df_iris` to rows where `petal length (cm)` is greater than 5.0. How many rows remain? What species are represented and in what counts?**
#
# *Hint:* Use boolean indexing and [`.value_counts()`](https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html)

# %%
### YOUR CODE HERE ###
df_long_petals = ...

#print(len(df_long_petals))
#print(df_long_petals['species'].value_counts())

# %% [markdown]
# **Q5 d) Write `df_iris` to `assets/data/iris_processed.csv` (without the index). Read it back and confirm the shape matches the original.**

# %%
### YOUR CODE HERE ###

# write to CSV

# read back and confirm shape
